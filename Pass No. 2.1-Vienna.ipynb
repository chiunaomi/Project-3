# %% [markdown]
# Project 3
# Naomi and Vienna

# %%
# %matplotlib notebook

from modsim import *

# %%
kg = UNITS.kilogram
m = UNITS.meter
s = UNITS.second
N = UNITS.newton
degree = UNITS.degree

# %%
#mass of person
mass = 62.1422 * kg

# %%
#constants
g = 9.81 * m/s**2
k_trampoline = 200 * kg/s**2

# %%
#starting conditions
h_init = 3 * m
v_init = 0 * m/s

# %%
init = State(y = 3 * m,
             v = 0 * m/s)

# %%
duration = 10

# %%
ts = linrange(0, duration, 1)

# %%
system = System(init=init, g=g, ts=ts)

# %%
def slope_func(state, t, system):
    y, v = state
    unpack(system)
    dydt = v
    dvdt = -g
    
    return dydt, dvdt

# %%
slope_func(init, 0, system)
# Out:
# (<Quantity(0.0, 'meter / second')>, <Quantity(-9.81, 'meter / second ** 2')>)

# %%
run_odeint(system, slope_func)

# %%
def plot_position(results):
    """Plot the results.
    
    results: DataFrame with position, `y`
    """
    newfig()
    plot(results.y, label='y')
        
    decorate(xlabel='Time (s)',
             ylabel='Position (m)')

# %%
plot_position(system.results)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
y = system.results.y

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
Y = interpolate(y)

# %%
T = interp_inverse(y, kind='cubic')

# %%
T_tramp = T(0)

# %%
T_tramp #time that it takes to hit the trampoline
# Out:
# array(0.6726445156717903)

# %%
'''condition = Condition(g = 9.8 * m/s**2,
                      mass = 62.1422 * kg,
                      k_trampoline = 200 * kg/s**2,
                      v_init = 0 * m/s,
                      angle = 270 * degree,
                      duration = 100 * s)'''
# Out:
# 'condition = Condition(g = 9.8 * m/s**2,\n                      mass = 62.1422 * kg,\n                      k_trampoline = 200 * kg/s**2,\n                      v_init = 0 * m/s,\n                      angle = 270 * degree,\n                      duration = 100 * s)'

# %%
'''def make_system(condition):
    unpack(condition)
    theta = np.deg2rad(angle)
    vx, vy = pol2cart(theta, v_init)
    init = State(vx=vx, vy=vy)
    ts = linspace(0, duration, 101)
    return System(init=init, g=g, mass=mass, ts=ts, k_trampoline=k_trampoline)'''
# Out:
# 'def make_system(condition):\n    unpack(condition)\n    theta = np.deg2rad(angle)\n    vx, vy = pol2cart(theta, v_init)\n    init = State(vx=vx, vy=vy)\n    ts = linspace(0, duration, 101)\n    return System(init=init, g=g, mass=mass, ts=ts, k_trampoline=k_trampoline)'

# %%
'''system = make_system(condition)
system'''
# Out:
# 'system = make_system(condition)\nsystem'

# %%
'''def slope_func(state, t, system):
    vx, vy = state
    unpack(system)
    a_grav= Vector(0, -g)
    v = Vector(vx, vy)'''
# Out:
# 'def slope_func(state, t, system):\n    vx, vy = state\n    unpack(system)\n    a_grav= Vector(0, -g)\n    v = Vector(vx, vy)'

# %%
#essential equations
"""
v_final_down = sqrt(2*g*d) #vertical velocity right before contact with trampoline
t = sqrt(2*d/g) #time to reach trampoline
p = mass * v_final_down #momentum at bottom
force_down = p/t #force applied to trampoline
tramp_displace = force_down / k_trampoline #trampoline displacement
tramp_PE = 0.5 * k_trampoline * tramp_displace**2 #elastic potential energy of trampoline


height_final = tramp_PE / (mass*g) #final height of person

v_initial_up = v_final_down
h_final = (v_initial_up**2)/(2*g)"""
# Out:
# '\nv_final_down = sqrt(2*g*d) #vertical velocity right before contact with trampoline\nt = sqrt(2*d/g) #time to reach trampoline\np = mass * v_final_down #momentum at bottom\nforce_down = p/t #force applied to trampoline\ntramp_displace = force_down / k_trampoline #trampoline displacement\ntramp_PE = 0.5 * k_trampoline * tramp_displace**2 #elastic potential energy of trampoline\n\n\nheight_final = tramp_PE / (mass*g) #final height of person\n\nv_initial_up = v_final_down\nh_final = (v_initial_up**2)/(2*g)'

# %%
def trampoline_something (mass, d, g=g, k=k_trampoline):
    v_final_down = sqrt(2*g*d) #vertical velocity right before contact with trampoline
    t = sqrt(2*d/g) #time to reach trampoline
    p = mass * v_final_down #momentum at bottom
    force_down = p/t #force applied to trampoline
    tramp_displace = force_down / k_trampoline #trampoline displacement
    tramp_PE = 0.5 * k_trampoline * tramp_displace**2 #elastic potential energy of trampoline
    return tramp_PE

# %%
tramp_PE = trampoline_something (mass, h_init, g, k_trampoline)

# %%
def final_height (tramp_PE, mass, g):
    height_final = tramp_PE / (mass*g)
    return height_final

# %%
final_height (tramp_PE, mass, g) #height without legs
# Out:
# <Quantity(1.5240374549999993, 'meter')>

# %%
run_odeint(system, final_height)
# Out:
# Before running scipy.integrate.odeint, I tried
#                  running the slope function you provided with the
#                  initial conditions in system and t=0, and I got
#                  the following error:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#     681             with np.errstate(all='ignore'):
# --> 682                 return na_op(lvalues, rvalues)
#     683         except Exception:
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     657             result = expressions.evaluate(op, str_rep, x, y,
# --> 658                                           raise_on_error=True, **eval_kwargs)
#     659         except TypeError:
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, raise_on_error, use_numexpr, **eval_kwargs)
#     210         return _evaluate(op, op_str, a, b, raise_on_error=raise_on_error,
# --> 211                          **eval_kwargs)
#     212     return _evaluate_standard(op, op_str, a, b, raise_on_error=raise_on_error)
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, raise_on_error, **eval_kwargs)
#      63     with np.errstate(all='ignore'):
# ---> 64         return op(a, b)
#      65
#
# C:\ProgramData\Miniconda3\lib\site-packages\pint\quantity.py in __rtruediv__(self, other)
#     760
# --> 761         return self.__class__(other_magnitude / self._magnitude, 1 / self._units)
#     762
#
# ZeroDivisionError: float division by zero
#
# During handling of the above exception, another exception occurred:
#
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-30-40ed92015b98> in <module>()
# ----> 1 run_odeint(system, final_height)
#
# ~\Documents\GitHub\Project-3\modsim.py in run_odeint(system, slope_func, **kwargs)
#     269                  the following error:"""
#     270         logger.error(msg)
# --> 271         raise(e)
#     272
#     273     # when odeint calls slope_func, it should pass `system` as
#
# ~\Documents\GitHub\Project-3\modsim.py in run_odeint(system, slope_func, **kwargs)
#     262     # try running the slope function with the initial conditions
#     263     try:
# --> 264         slope_func(init, ts[0], system)
#     265     except Exception as e:
#     266         msg = """Before running scipy.integrate.odeint, I tried
#
# <ipython-input-28-dfa97fae1b8e> in final_height(tramp_PE, mass, g)
#       1 def final_height (tramp_PE, mass, g):
# ----> 2     height_final = tramp_PE / (mass*g)
#       3     return height_final
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\ops.py in wrapper(left, right, name, na_op)
#     719                 lvalues = lvalues.values
#     720
# --> 721         result = wrap_results(safe_na_op(lvalues, rvalues))
#     722         return construct_result(
#     723             left,
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#     690                 if is_object_dtype(lvalues):
#     691                     return libalgos.arrmap_object(lvalues,
# --> 692                                                   lambda x: op(x, rvalues))
#     693             raise
#     694
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.arrmap_object (pandas\_libs\algos.c:31954)()
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\ops.py in <lambda>(x)
#     690                 if is_object_dtype(lvalues):
#     691                     return libalgos.arrmap_object(lvalues,
# --> 692                                                   lambda x: op(x, rvalues))
#     693             raise
#     694
#
# C:\ProgramData\Miniconda3\lib\site-packages\pint\quantity.py in __rtruediv__(self, other)
#     759             self = self.to_root_units()
#     760
# --> 761         return self.__class__(other_magnitude / self._magnitude, 1 / self._units)
#     762
#     763     def __rfloordiv__(self, other):
#
# ZeroDivisionError: float division by zero

# %%
newfig()
plot(system.results, label = "final height")
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-31-c8af3aa10e86> in <module>()
#       1 newfig()
# ----> 2 plot(system.results, label = "final height")
#
# ~\Documents\GitHub\Project-3\modsim.py in plot(*args, **kwargs)
#     530
#     531     axes = plt.gca()
# --> 532     axes.relim()
#     533     axes.autoscale_view(True, True, True)
#     534     axes.margins(0.02)
#
# C:\ProgramData\Miniconda3\lib\site-packages\matplotlib\axes\_base.py in relim(self, visible_only)
#    1941         for line in self.lines:
#    1942             if not visible_only or line.get_visible():
# -> 1943                 self._update_line_limits(line)
#    1944
#    1945         for p in self.patches:
#
# C:\ProgramData\Miniconda3\lib\site-packages\matplotlib\axes\_base.py in _update_line_limits(self, line)
#    1813         Figures out the data limit of the given line, updating self.dataLim.
#    1814         """
# -> 1815         path = line.get_path()
#    1816         if path.vertices.size == 0:
#    1817             return
#
# C:\ProgramData\Miniconda3\lib\site-packages\matplotlib\lines.py in get_path(self)
#     987         """
#     988         if self._invalidy or self._invalidx:
# --> 989             self.recache()
#     990         return self._path
#     991
#
# C:\ProgramData\Miniconda3\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     694
#     695         if len(x) != len(y):
# --> 696             raise RuntimeError('xdata and ydata must be the same length')
#     697
#     698         self._xy = np.empty((len(x), 2), dtype=np.float_)
#
# RuntimeError: xdata and ydata must be the same length
